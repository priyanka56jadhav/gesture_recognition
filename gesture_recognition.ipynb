# %% [markdown]
# # Gesture Recognition
# In this project, we are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Importing required libraries.

# %%
import numpy as np
import os
import cv2
from matplotlib.pyplot import imread
import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
import os
os.environ['PYTHONHASHSEED']="30"
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K
import keras as Keras

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# train and validatiaon data creator with ablation
# when ablation is 10, then 10 folders for each label will be selected.
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
train_doc, val_doc = get_data('/content/drive/MyDrive/Project_data1/Project_data/', ablation=None)
batch_size = 32 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# generator with augmentation for train data
# from PIL import Image
from skimage.transform import resize
def generator(source_path, folder_list, batch_size, is_train = False, augmention = False, debug=False):
    # print('\nSource path = ', source_path, '; batch size =', batch_size)
    img_idx = seq_idx #create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        # doubling the data for augmentation
        if is_train and augmention:
            t = np.concatenate((np.random.permutation(folder_list), np.random.permutation(folder_list)))
        else:
            t = np.random.permutation(folder_list)

        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ folder_str.split(';')[0]) # read all the images in the folder
                # randomly enabling augmentation and augmentation type
                aug_type = None
                if is_train and augmention and rn.randint(0,1) == 1:
                    aug_type = rn.randint(0, 4) #randomly selecting augmentation type
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    # plotting original images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # making the rectangle images into square by cropping sides
                    # so the aspect ration can be mantained while resizing.
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]
                    # image = Image.open(image)
                    # resized_im = image.resize((y, z))
                    # new_image.save('image_400.jpg')
                    # resized_im = resize(image, size=(y,z))
                    resized_im = resize(image, (y,z))

                    if aug_type is not None:
                        if aug_type == 0: # edge Enhancement
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.EDGE_ENHANCE))
                        elif aug_type == 1: # adding gaussian blur
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.GaussianBlur(1)))
                        elif aug_type == 2: # enchancing image detailing
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.DETAIL))
                        elif aug_type == 3: # sharpening image
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.SHARPEN))
                        elif aug_type == 4: # Brightness enhancement
                            resized_im = np.array(ImageEnhance.Brightness((Image.fromarray(resized_im, 'RGB'))).enhance(1.5))
                    # plotting rezised images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+x+1)
                        plt.imshow(resized_im)

                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255 #normalise and feed in the image

                batch_labels[folder, int(folder_str.strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/content/drive/MyDrive/Project_data1/Project_data/train'
val_path =  '/content/drive/MyDrive/Project_data1/Project_data/val'

#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 50 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %%
# testing generative
test_gen = generator(train_path, train_doc, 1, is_train = True, augmention = True, debug = True)
d = next(test_gen)[1]

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from keras.layers import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
np.random.seed(30)

# %% [markdown]
# ### Experiment - 1 & 2
# **Conv3D**

# %%
# model = Sequential()
# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(MaxPooling3D(pool_size=2))

# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=2))

# model.add(Flatten())
# model.add(Dense(256, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 3
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(256, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(3, 2, 2)))

# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 4
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 5 & 6
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 7 & 8
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 9
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 10
# **Conv3D**

# %%
# loss: 0.1388 - categorical_accuracy: 0.9539 - val_loss: 0.1661 - val_categorical_accuracy: 0.9297
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(GlobalAveragePooling3D())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 11
# **TimeDistributed Conv2D + GRU**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(GlobalAveragePooling2D()))
# model.add(TimeDistributed(Dense(64, activation='relu')))
# model.add(BatchNormalization())

# model.add(GRU(128))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 12
# **TimeDistributed Conv2D + GRU**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(TimeDistributed(GlobalAveragePooling2D()))
# model.add(TimeDistributed(Dense(64, activation='relu')))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(GRU(128))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 13
# **TimeDistributed Conv2D + Dense**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(128, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(GlobalAveragePooling3D())
# model.add(Dense(256, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 14
# **TimeDistributed + ConvLSTM2D**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Conv2D(16, (3,3), activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(
#     ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Dense(64, activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(GlobalAveragePooling2D())
# model.add(Dense(64, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# # Final Model

# %%
model = Sequential()
model.add(TimeDistributed(
    Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Conv2D(16, (3,3), activation='relu'))
)
model.add(BatchNormalization())
model.add(
    ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Dense(64, activation='relu'))
)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDist  (None, 10, 118, 118, 8)   224
#  ributed)
#
#  batch_normalization (Batch  (None, 10, 118, 118, 8)   32
#  Normalization)
#
#  time_distributed_1 (TimeDi  (None, 10, 116, 116, 16   1168
#  stributed)                  )
#
#  batch_normalization_1 (Bat  (None, 10, 116, 116, 16   64
#  chNormalization)            )
#
#  conv_lstm2d (ConvLSTM2D)    (None, 114, 114, 8)       6944
#
#  batch_normalization_2 (Bat  (None, 114, 114, 8)       32
#  chNormalization)
#
#  time_distributed_2 (TimeDi  (None, 114, 114, 64)      576
#  stributed)
#
#  batch_normalization_3 (Bat  (None, 114, 114, 64)      256
#  chNormalization)
#
#  global_average_pooling2d (  (None, 64)                0
#  GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13781 (53.83 KB)
# Trainable params: 13589 (53.08 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size, is_train = True, augmention = enable_augmentation)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init_exp_16' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here

callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                        callbacks=callbacks_list, validation_data=val_generator,
                        validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/50
# 21/21 [==============================] - ETA: 0s - loss: 1.4536 - categorical_accuracy: 0.3259
# Epoch 1: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00001-1.45363-0.32589-1.25820-0.16406.h5
# 21/21 [==============================] - 3504s 173s/step - loss: 1.4536 - categorical_accuracy: 0.3259 - val_loss: 1.2582 - val_categorical_accuracy: 0.1641 - lr: 0.0010
# Epoch 2/50
# 21/21 [==============================] - ETA: 0s - loss: 1.3313 - categorical_accuracy: 0.4315
# Epoch 2: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00002-1.33126-0.43155-1.26554-0.10938.h5
# 21/21 [==============================] - 694s 33s/step - loss: 1.3313 - categorical_accuracy: 0.4315 - val_loss: 1.2655 - val_categorical_accuracy: 0.1094 - lr: 0.0010
# Epoch 3/50
# 21/21 [==============================] - ETA: 0s - loss: 1.2923 - categorical_accuracy: 0.4420
# Epoch 3: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00003-1.29226-0.44196-1.27021-0.13281.h5
# 21/21 [==============================] - 705s 34s/step - loss: 1.2923 - categorical_accuracy: 0.4420 - val_loss: 1.2702 - val_categorical_accuracy: 0.1328 - lr: 0.0010
# Epoch 4/50
# 21/21 [==============================] - ETA: 0s - loss: 1.1926 - categorical_accuracy: 0.4836
# Epoch 4: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00004-1.19263-0.48363-1.27739-0.15625.h5
# 21/21 [==============================] - 687s 33s/step - loss: 1.1926 - categorical_accuracy: 0.4836 - val_loss: 1.2774 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 5/50
# 21/21 [==============================] - ETA: 0s - loss: 1.1864 - categorical_accuracy: 0.4643
# Epoch 5: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00005-1.18645-0.46429-1.29122-0.12500.h5
# 21/21 [==============================] - 645s 31s/step - loss: 1.1864 - categorical_accuracy: 0.4643 - val_loss: 1.2912 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 6/50
# 21/21 [==============================] - ETA: 0s - loss: 1.1312 - categorical_accuracy: 0.4821
# Epoch 6: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00006-1.13122-0.48214-1.28118-0.41406.h5
# 21/21 [==============================] - 611s 29s/step - loss: 1.1312 - categorical_accuracy: 0.4821 - val_loss: 1.2812 - val_categorical_accuracy: 0.4141 - lr: 0.0010
# Epoch 7/50
# 21/21 [==============================] - ETA: 0s - loss: 1.1175 - categorical_accuracy: 0.5283
# Epoch 7: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00007-1.11745-0.52827-1.29086-0.16406.h5
# 21/21 [==============================] - 609s 29s/step - loss: 1.1175 - categorical_accuracy: 0.5283 - val_loss: 1.2909 - val_categorical_accuracy: 0.1641 - lr: 0.0010
# Epoch 8/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0798 - categorical_accuracy: 0.5521
# Epoch 8: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00008-1.07977-0.55208-1.28740-0.36719.h5
# 21/21 [==============================] - 663s 32s/step - loss: 1.0798 - categorical_accuracy: 0.5521 - val_loss: 1.2874 - val_categorical_accuracy: 0.3672 - lr: 0.0010
# Epoch 9/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0423 - categorical_accuracy: 0.5625
# Epoch 9: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00009-1.04227-0.56250-1.30934-0.36719.h5
# 21/21 [==============================] - 604s 29s/step - loss: 1.0423 - categorical_accuracy: 0.5625 - val_loss: 1.3093 - val_categorical_accuracy: 0.3672 - lr: 0.0010
# Epoch 10/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9891 - categorical_accuracy: 0.5848
# Epoch 10: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00010-0.98910-0.58482-1.29540-0.37500.h5
# 21/21 [==============================] - 629s 30s/step - loss: 0.9891 - categorical_accuracy: 0.5848 - val_loss: 1.2954 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 11/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0004 - categorical_accuracy: 0.5759
# Epoch 11: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00011-1.00040-0.57589-1.33159-0.35938.h5
# 21/21 [==============================] - 626s 30s/step - loss: 1.0004 - categorical_accuracy: 0.5759 - val_loss: 1.3316 - val_categorical_accuracy: 0.3594 - lr: 0.0010
# Epoch 12/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9793 - categorical_accuracy: 0.5908
# Epoch 12: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00012-0.97930-0.59077-1.31173-0.14844.h5
# 21/21 [==============================] - 621s 30s/step - loss: 0.9793 - categorical_accuracy: 0.5908 - val_loss: 1.3117 - val_categorical_accuracy: 0.1484 - lr: 0.0010
# Epoch 13/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9011 - categorical_accuracy: 0.6384
# Epoch 13: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00013-0.90110-0.63839-1.35203-0.35938.h5
# 21/21 [==============================] - 616s 29s/step - loss: 0.9011 - categorical_accuracy: 0.6384 - val_loss: 1.3520 - val_categorical_accuracy: 0.3594 - lr: 0.0010
# Epoch 14/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9615 - categorical_accuracy: 0.5804
# Epoch 14: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00014-0.96152-0.58036-1.54208-0.36719.h5
# 21/21 [==============================] - 630s 30s/step - loss: 0.9615 - categorical_accuracy: 0.5804 - val_loss: 1.5421 - val_categorical_accuracy: 0.3672 - lr: 0.0010
# Epoch 15/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9197 - categorical_accuracy: 0.6176
# Epoch 15: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00015-0.91975-0.61756-2.27673-0.34375.h5
# 21/21 [==============================] - 611s 29s/step - loss: 0.9197 - categorical_accuracy: 0.6176 - val_loss: 2.2767 - val_categorical_accuracy: 0.3438 - lr: 0.0010
# Epoch 16/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8277 - categorical_accuracy: 0.6771
# Epoch 16: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00016-0.82774-0.67708-2.18426-0.35156.h5
# 21/21 [==============================] - 606s 29s/step - loss: 0.8277 - categorical_accuracy: 0.6771 - val_loss: 2.1843 - val_categorical_accuracy: 0.3516 - lr: 0.0010
# Epoch 17/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8010 - categorical_accuracy: 0.6875
# Epoch 17: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00017-0.80103-0.68750-2.12104-0.37500.h5
# 21/21 [==============================] - 598s 29s/step - loss: 0.8010 - categorical_accuracy: 0.6875 - val_loss: 2.1210 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 18/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8205 - categorical_accuracy: 0.6711
# Epoch 18: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00018-0.82055-0.67113-2.18405-0.40625.h5
# 21/21 [==============================] - 605s 29s/step - loss: 0.8205 - categorical_accuracy: 0.6711 - val_loss: 2.1840 - val_categorical_accuracy: 0.4062 - lr: 0.0010
# Epoch 19/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8269 - categorical_accuracy: 0.6488
# Epoch 19: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00019-0.82689-0.64881-1.84436-0.35938.h5
# 21/21 [==============================] - 605s 29s/step - loss: 0.8269 - categorical_accuracy: 0.6488 - val_loss: 1.8444 - val_categorical_accuracy: 0.3594 - lr: 0.0010
# Epoch 20/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9113 - categorical_accuracy: 0.6176
# Epoch 20: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00020-0.91127-0.61756-3.82966-0.14844.h5
# 21/21 [==============================] - 658s 32s/step - loss: 0.9113 - categorical_accuracy: 0.6176 - val_loss: 3.8297 - val_categorical_accuracy: 0.1484 - lr: 0.0010
# Epoch 21/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8664 - categorical_accuracy: 0.6473
# Epoch 21: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00021-0.86638-0.64732-6.76945-0.17969.h5
# 21/21 [==============================] - 620s 30s/step - loss: 0.8664 - categorical_accuracy: 0.6473 - val_loss: 6.7694 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 22/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8178 - categorical_accuracy: 0.6652
# Epoch 22: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00022-0.81778-0.66518-13.11193-0.14844.h5
# 21/21 [==============================] - 616s 29s/step - loss: 0.8178 - categorical_accuracy: 0.6652 - val_loss: 13.1119 - val_categorical_accuracy: 0.1484 - lr: 0.0010
# Epoch 23/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7628 - categorical_accuracy: 0.6830
# Epoch 23: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00023-0.76282-0.68304-16.17808-0.17969.h5
# 21/21 [==============================] - 610s 29s/step - loss: 0.7628 - categorical_accuracy: 0.6830 - val_loss: 16.1781 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 24/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7659 - categorical_accuracy: 0.6801
# Epoch 24: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00024-0.76586-0.68006-18.26399-0.15625.h5
# 21/21 [==============================] - 588s 28s/step - loss: 0.7659 - categorical_accuracy: 0.6801 - val_loss: 18.2640 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 25/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7155 - categorical_accuracy: 0.7068
# Epoch 25: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00025-0.71549-0.70685-14.59881-0.14844.h5
# 21/21 [==============================] - 587s 28s/step - loss: 0.7155 - categorical_accuracy: 0.7068 - val_loss: 14.5988 - val_categorical_accuracy: 0.1484 - lr: 0.0010
# Epoch 26/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7404 - categorical_accuracy: 0.6875
# Epoch 26: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00026-0.74040-0.68750-5.88946-0.25000.h5
# 21/21 [==============================] - 587s 28s/step - loss: 0.7404 - categorical_accuracy: 0.6875 - val_loss: 5.8895 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 27/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8034 - categorical_accuracy: 0.6548
# Epoch 27: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00027-0.80339-0.65476-3.25661-0.18750.h5
# 21/21 [==============================] - 589s 28s/step - loss: 0.8034 - categorical_accuracy: 0.6548 - val_loss: 3.2566 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 28/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7327 - categorical_accuracy: 0.6994
# Epoch 28: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00028-0.73272-0.69940-3.68577-0.20312.h5
# 21/21 [==============================] - 593s 28s/step - loss: 0.7327 - categorical_accuracy: 0.6994 - val_loss: 3.6858 - val_categorical_accuracy: 0.2031 - lr: 0.0010
# Epoch 29/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6968 - categorical_accuracy: 0.7202
# Epoch 29: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00029-0.69681-0.72024-3.17187-0.17969.h5
# 21/21 [==============================] - 592s 28s/step - loss: 0.6968 - categorical_accuracy: 0.7202 - val_loss: 3.1719 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 30/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7222 - categorical_accuracy: 0.6964
# Epoch 30: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00030-0.72219-0.69643-8.84248-0.37500.h5
# 21/21 [==============================] - 597s 28s/step - loss: 0.7222 - categorical_accuracy: 0.6964 - val_loss: 8.8425 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 31/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6550 - categorical_accuracy: 0.7262
# Epoch 31: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00031-0.65503-0.72619-35.64272-0.12500.h5
# 21/21 [==============================] - 616s 29s/step - loss: 0.6550 - categorical_accuracy: 0.7262 - val_loss: 35.6427 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 32/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6286 - categorical_accuracy: 0.7470
# Epoch 32: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00032-0.62862-0.74702-23.73149-0.17969.h5
# 21/21 [==============================] - 607s 29s/step - loss: 0.6286 - categorical_accuracy: 0.7470 - val_loss: 23.7315 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 33/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6461 - categorical_accuracy: 0.7262
# Epoch 33: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00033-0.64611-0.72619-27.20691-0.16406.h5
# 21/21 [==============================] - 609s 29s/step - loss: 0.6461 - categorical_accuracy: 0.7262 - val_loss: 27.2069 - val_categorical_accuracy: 0.1641 - lr: 0.0010
# Epoch 34/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6930 - categorical_accuracy: 0.7143
# Epoch 34: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00034-0.69297-0.71429-44.58006-0.14062.h5
# 21/21 [==============================] - 603s 29s/step - loss: 0.6930 - categorical_accuracy: 0.7143 - val_loss: 44.5801 - val_categorical_accuracy: 0.1406 - lr: 0.0010
# Epoch 35/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9758 - categorical_accuracy: 0.5848
# Epoch 35: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00035-0.97584-0.58482-35.89563-0.18750.h5
# 21/21 [==============================] - 586s 28s/step - loss: 0.9758 - categorical_accuracy: 0.5848 - val_loss: 35.8956 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 36/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8739 - categorical_accuracy: 0.6473
# Epoch 36: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00036-0.87389-0.64732-31.39667-0.17188.h5
# 21/21 [==============================] - 591s 28s/step - loss: 0.8739 - categorical_accuracy: 0.6473 - val_loss: 31.3967 - val_categorical_accuracy: 0.1719 - lr: 0.0010
# Epoch 37/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0405 - categorical_accuracy: 0.5670
# Epoch 37: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00037-1.04052-0.56696-23.79594-0.16406.h5
# 21/21 [==============================] - 593s 28s/step - loss: 1.0405 - categorical_accuracy: 0.5670 - val_loss: 23.7959 - val_categorical_accuracy: 0.1641 - lr: 0.0010
# Epoch 38/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8421 - categorical_accuracy: 0.6473
# Epoch 38: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00038-0.84212-0.64732-24.38677-0.17188.h5
# 21/21 [==============================] - 593s 28s/step - loss: 0.8421 - categorical_accuracy: 0.6473 - val_loss: 24.3868 - val_categorical_accuracy: 0.1719 - lr: 0.0010
# Epoch 39/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8679 - categorical_accuracy: 0.6280
# Epoch 39: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00039-0.86791-0.62798-14.25118-0.18750.h5
# 21/21 [==============================] - 588s 28s/step - loss: 0.8679 - categorical_accuracy: 0.6280 - val_loss: 14.2512 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 40/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8010 - categorical_accuracy: 0.6652
# Epoch 40: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00040-0.80096-0.66518-14.74285-0.13281.h5
# 21/21 [==============================] - 597s 29s/step - loss: 0.8010 - categorical_accuracy: 0.6652 - val_loss: 14.7429 - val_categorical_accuracy: 0.1328 - lr: 0.0010
# Epoch 41/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7332 - categorical_accuracy: 0.6905
# Epoch 41: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00041-0.73318-0.69048-14.64932-0.15625.h5
# 21/21 [==============================] - 600s 29s/step - loss: 0.7332 - categorical_accuracy: 0.6905 - val_loss: 14.6493 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 42/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7889 - categorical_accuracy: 0.6652
# Epoch 42: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00042-0.78893-0.66518-15.54342-0.19531.h5
# 21/21 [==============================] - 581s 28s/step - loss: 0.7889 - categorical_accuracy: 0.6652 - val_loss: 15.5434 - val_categorical_accuracy: 0.1953 - lr: 0.0010
# Epoch 43/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6924 - categorical_accuracy: 0.7158
# Epoch 43: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00043-0.69242-0.71577-17.09379-0.17969.h5
# 21/21 [==============================] - 568s 27s/step - loss: 0.6924 - categorical_accuracy: 0.7158 - val_loss: 17.0938 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 44/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7073 - categorical_accuracy: 0.6756
# Epoch 44: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00044-0.70730-0.67560-16.56613-0.12500.h5
# 21/21 [==============================] - 598s 29s/step - loss: 0.7073 - categorical_accuracy: 0.6756 - val_loss: 16.5661 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 45/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6587 - categorical_accuracy: 0.7262
# Epoch 45: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00045-0.65868-0.72619-18.10433-0.18750.h5
# 21/21 [==============================] - 589s 28s/step - loss: 0.6587 - categorical_accuracy: 0.7262 - val_loss: 18.1043 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 46/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6661 - categorical_accuracy: 0.7202
# Epoch 46: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00046-0.66607-0.72024-16.40757-0.17188.h5
# 21/21 [==============================] - 585s 28s/step - loss: 0.6661 - categorical_accuracy: 0.7202 - val_loss: 16.4076 - val_categorical_accuracy: 0.1719 - lr: 0.0010
# Epoch 47/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6361 - categorical_accuracy: 0.7366
# Epoch 47: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00047-0.63607-0.73661-29.62137-0.16406.h5
# 21/21 [==============================] - 581s 28s/step - loss: 0.6361 - categorical_accuracy: 0.7366 - val_loss: 29.6214 - val_categorical_accuracy: 0.1641 - lr: 0.0010
# Epoch 48/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6181 - categorical_accuracy: 0.7366
# Epoch 48: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00048-0.61805-0.73661-12.91990-0.20312.h5
# 21/21 [==============================] - 649s 31s/step - loss: 0.6181 - categorical_accuracy: 0.7366 - val_loss: 12.9199 - val_categorical_accuracy: 0.2031 - lr: 0.0010
# Epoch 49/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6811 - categorical_accuracy: 0.7098
# Epoch 49: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00049-0.68114-0.70982-26.79139-0.17188.h5
# 21/21 [==============================] - 654s 31s/step - loss: 0.6811 - categorical_accuracy: 0.7098 - val_loss: 26.7914 - val_categorical_accuracy: 0.1719 - lr: 0.0010
# Epoch 50/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6306 - categorical_accuracy: 0.7500
# Epoch 50: saving model to model_init_exp_16_2024-04-2104_02_57.709462/model-00050-0.63064-0.75000-31.17141-0.13281.h5
# 21/21 [==============================] - 619s 30s/step - loss: 0.6306 - categorical_accuracy: 0.7500 - val_loss: 31.1714 - val_categorical_accuracy: 0.1328 - lr: 0.0010

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
